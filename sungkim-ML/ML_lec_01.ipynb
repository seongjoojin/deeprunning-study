# %% [markdown]
# # Lecture1. Machine Learning Basics
#
# 머신러닝 종류
#
# Supervised/Unsupervised learning 지도/비지도 학습
#
# Supervised learning : Most common problem type in ML
#
# 지도학습의 종류
#
# 1.regression 2.binary classification 3.multi-label classification
#
# # ML lab01. Tensorflow Basics
#
# Tensorflow is an open source software library for numerial computation using data flow graphs.

# %%
import tensorflow as tf

# Create a constant op
# This op is added as a node to the default graph
hello = tf.constant("Hello,Tensorflow!")

# start a TF session
sess = tf.Session()

# run the op and get result
print(sess.run(hello))
# Out:
# b'Hello,Tensorflow!'

# %%
node1 = tf.constant(3.0, tf.float32)
node2 = tf.constant(4.0) # also tf.float32 implicitly
node3 = tf.add(node1, node2)

print('node1:',node1,'node2:',node2)
print('node3:',node3)

sess = tf.Session()
print('sess.run(node1, node2):',sess.run([node1, node2]))
print('sess.run(node3):',sess.run(node3))
# Out:
# node1: Tensor("Const_1:0", shape=(), dtype=float32) node2: Tensor("Const_2:0", shape=(), dtype=float32)
# node3: Tensor("Add:0", shape=(), dtype=float32)
# sess.run(node1, node2): [3.0, 4.0]
# sess.run(node3): 7.0

# %% [markdown]
# ## TensorFlow Mechanics
#
# 1. Build graph using TensorFlow operations
# 2. feed data and run graph (operation) **sess.run(op)**
# 3. update variables in the graph (and return values)

# %%
a = tf.placeholder(tf.float32)
b = tf.placeholder(tf.float32)
adder_node = a + b # + provides a shortcut for tf.add(a, b)

print(sess.run(adder_node, feed_dict={a: 3,b: 4.5}))
print(sess.run(adder_node, feed_dict={a: [1, 3], b: [2, 4]}))
# Out:
# 7.5
# [3. 7.]

# %% [markdown]
# ## Tensor

# %%
3 # a rank 0 tensor; this is a scalra with shape []
[1., 2., 3.] # a rank 1 tensor; this is a vector with shape [3]
[[1., 2., 3.],[4., 5., 6.]] # a rank 2 tensor; a martix with shape [2,3]
[[[1.,2.,3.]], [[7., 8., 9.]]] # a rank 3 tensor with shape [2, 1, 3]

# %% [markdown]
# ## Tensor Rank
#
# ![대체 텍스트](https://i.imgur.com/CuFP5nn.png)
#
# ## Tensor Shape
#
# ![대체 텍스트](https://i.imgur.com/8L0LlMj.png)
#
# ## Tensor Data type
#
# ![대체 텍스트](https://i.imgur.com/rsMHyMQ.png)
