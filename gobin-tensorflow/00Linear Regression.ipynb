# %%
import tensorflow as tf

x_data = [1, 2, 3]
y_data = [1, 2, 3]

W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))

# name: 나중에 텐서보드등으로 값의 변화를 추적하거나 살펴보기 쉽게 하기 위해 이름을 붙여줍니다.
X = tf.placeholder(tf.float32, name="X")
Y = tf.placeholder(tf.float32, name="Y")
print(X)
print(Y)

# X 와 Y 의 상관 관계를 분석하기 위한 가설 수식을 작성합니다.
# y = W * x + b
# W 와 X 가 행렬이 아니므로 tf.matmul 이 아니라 기본 곱셈 기호를 사용했습니다.
hypothesis = W * X + b

# 손실 함수를 작성합니다.
# mean(h - Y)^2 : 예측값과 실제값의 거리를 비용(손실) 함수로 정합니다.
cost = tf.reduce_mean(tf.square(hypothesis - Y))
# 텐서플로우에 기본적으로 포함되어 있는 함수를 이용해 경사 하강법 최적화를 수행합니다.
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)
# 비용을 최소화 하는 것이 최종 목표
train_op = optimizer.minimize(cost)

# 세션을 생성하고 초기화합니다.
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    # 최적화를 100번 수행합니다.
    for step in range(100):
        # sess.run 을 통해 train_op 와 cost 그래프를 계산합니다.
        # 이 때, 가설 수식에 넣어야 할 실제값을 feed_dict 을 통해 전달합니다.
        _, cost_val = sess.run([train_op, cost], feed_dict={X: x_data, Y: y_data})
        
        print("Step : ",step)
        print("X : ",sess.run(X, feed_dict={X:x_data}))
        print("W : ",sess.run(W))
        print("b : ",sess.run(b))
        print("hypothesis : ", sess.run(hypothesis, feed_dict={X: x_data, Y: y_data}))
        print("cost : ", sess.run(cost, feed_dict={X: x_data, Y: y_data}))

    # 최적화가 완료된 모델에 테스트 값을 넣고 결과가 잘 나오는지 확인해봅니다.
    print("\n=== Test ===")
    print("X: 5, Y:", sess.run(hypothesis, feed_dict={X: 5}))
    print("X: 2.5, Y:", sess.run(hypothesis, feed_dict={X: 2.5}))
# Out:
# Tensor("X_3:0", dtype=float32)
# Tensor("Y_3:0", dtype=float32)
# ('Step : ', 0)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9869577], dtype=float32))
# ('b : ', array([0.20508671], dtype=float32))
# ('hypothesis : ', array([1.1920445, 2.1790023, 3.1659598], dtype=float32))
# ('cost : ', 0.03215519)
# ('Step : ', 1)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.91709584], dtype=float32))
# ('b : ', array([0.16928627], dtype=float32))
# ('hypothesis : ', array([1.0863822, 2.003478 , 2.9205737], dtype=float32))
# ('cost : ', 0.0045941696)
# ('Step : ', 2)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9267585], dtype=float32))
# ('b : ', array([0.16859066], dtype=float32))
# ('hypothesis : ', array([1.0953492, 2.0221076, 2.9488664], dtype=float32))
# ('cost : ', 0.0040649544)
# ('Step : ', 3)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.92768097], dtype=float32))
# ('b : ', array([0.16416912], dtype=float32))
# ('hypothesis : ', array([1.09185 , 2.019531, 2.947212], dtype=float32))
# ('cost : ', 0.0038681552)
# ('Step : ', 4)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.92951113], dtype=float32))
# ('b : ', array([0.16026291], dtype=float32))
# ('hypothesis : ', array([1.089774 , 2.0192852, 2.9487963], dtype=float32))
# ('cost : ', 0.0036843715)
# ('Step : ', 5)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.93119556], dtype=float32))
# ('b : ', array([0.15640588], dtype=float32))
# ('hypothesis : ', array([1.0876014, 2.018797 , 2.9499927], dtype=float32))
# ('cost : ', 0.003509356)
# ('Step : ', 6)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.93285066], dtype=float32))
# ('b : ', array([0.15264648], dtype=float32))
# ('hypothesis : ', array([1.0854971, 2.0183477, 2.9511986], dtype=float32))
# ('cost : ', 0.00334266)
# ('Step : ', 7)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.93446475], dtype=float32))
# ('b : ', array([0.14897692], dtype=float32))
# ('hypothesis : ', array([1.0834417, 2.0179064, 2.9523711], dtype=float32))
# ('cost : ', 0.003183891)
# ('Step : ', 8)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9360402], dtype=float32))
# ('b : ', array([0.14539564], dtype=float32))
# ('hypothesis : ', array([1.0814359, 2.017476 , 2.9535165], dtype=float32))
# ('cost : ', 0.0030326464)
# ('Step : ', 9)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9375777], dtype=float32))
# ('b : ', array([0.1419004], dtype=float32))
# ('hypothesis : ', array([1.0794781, 2.0170557, 2.9546335], dtype=float32))
# ('cost : ', 0.0028885985)
# ('Step : ', 10)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9390784], dtype=float32))
# ('b : ', array([0.13848925], dtype=float32))
# ('hypothesis : ', array([1.0775676, 2.016646 , 2.9557245], dtype=float32))
# ('cost : ', 0.002751379)
# ('Step : ', 11)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9405429], dtype=float32))
# ('b : ', array([0.13516004], dtype=float32))
# ('hypothesis : ', array([1.0757029, 2.0162458, 2.9567885], dtype=float32))
# ('cost : ', 0.0026206959)
# ('Step : ', 12)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9419722], dtype=float32))
# ('b : ', array([0.13191089], dtype=float32))
# ('hypothesis : ', array([1.073883 , 2.0158553, 2.9578273], dtype=float32))
# ('cost : ', 0.0024962104)
# ('Step : ', 13)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9433671], dtype=float32))
# ('b : ', array([0.12873985], dtype=float32))
# ('hypothesis : ', array([1.072107 , 2.015474 , 2.9588413], dtype=float32))
# ('cost : ', 0.0023776323)
# ('Step : ', 14)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9447285], dtype=float32))
# ('b : ', array([0.12564503], dtype=float32))
# ('hypothesis : ', array([1.0703735, 2.015102 , 2.9598305], dtype=float32))
# ('cost : ', 0.0022646964)
# ('Step : ', 15)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.94605726], dtype=float32))
# ('b : ', array([0.12262463], dtype=float32))
# ('hypothesis : ', array([1.0686818, 2.014739 , 2.9607964], dtype=float32))
# ('cost : ', 0.0021571198)
# ('Step : ', 16)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.947354], dtype=float32))
# ('b : ', array([0.11967681], dtype=float32))
# ('hypothesis : ', array([1.0670308, 2.0143847, 2.9617388], dtype=float32))
# ('cost : ', 0.002054655)
# ('Step : ', 17)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.94861954], dtype=float32))
# ('b : ', array([0.11679985], dtype=float32))
# ('hypothesis : ', array([1.0654194, 2.014039 , 2.9626584], dtype=float32))
# ('cost : ', 0.0019570638)
# ('Step : ', 18)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9498547], dtype=float32))
# ('b : ', array([0.11399207], dtype=float32))
# ('hypothesis : ', array([1.0638467, 2.0137014, 2.963556 ], dtype=float32))
# ('cost : ', 0.0018640977)
# ('Step : ', 19)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9510602], dtype=float32))
# ('b : ', array([0.11125179], dtype=float32))
# ('hypothesis : ', array([1.062312 , 2.0133722, 2.9644322], dtype=float32))
# ('cost : ', 0.0017755558)
# ('Step : ', 20)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.95223665], dtype=float32))
# ('b : ', array([0.10857736], dtype=float32))
# ('hypothesis : ', array([1.060814 , 2.0130506, 2.9652872], dtype=float32))
# ('cost : ', 0.0016912135)
# ('Step : ', 21)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9533849], dtype=float32))
# ('b : ', array([0.10596724], dtype=float32))
# ('hypothesis : ', array([1.0593522, 2.012737 , 2.966122 ], dtype=float32))
# ('cost : ', 0.0016108785)
# ('Step : ', 22)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9545054], dtype=float32))
# ('b : ', array([0.10341983], dtype=float32))
# ('hypothesis : ', array([1.0579252, 2.0124307, 2.9669359], dtype=float32))
# ('cost : ', 0.0015343633)
# ('Step : ', 23)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9555991], dtype=float32))
# ('b : ', array([0.10093372], dtype=float32))
# ('hypothesis : ', array([1.0565329, 2.012132 , 2.9677312], dtype=float32))
# ('cost : ', 0.0014614736)
# ('Step : ', 24)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9566664], dtype=float32))
# ('b : ', array([0.09850731], dtype=float32))
# ('hypothesis : ', array([1.0551738, 2.01184  , 2.9685066], dtype=float32))
# ('cost : ', 0.0013920558)
# ('Step : ', 25)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9577082], dtype=float32))
# ('b : ', array([0.09613928], dtype=float32))
# ('hypothesis : ', array([1.0538474, 2.0115557, 2.9692638], dtype=float32))
# ('cost : ', 0.0013259313)
# ('Step : ', 26)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.95872486], dtype=float32))
# ('b : ', array([0.09382816], dtype=float32))
# ('hypothesis : ', array([1.052553 , 2.011278 , 2.9700027], dtype=float32))
# ('cost : ', 0.0012629521)
# ('Step : ', 27)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9597171], dtype=float32))
# ('b : ', array([0.09157258], dtype=float32))
# ('hypothesis : ', array([1.0512897, 2.0110068, 2.9707239], dtype=float32))
# ('cost : ', 0.0012029578)
# ('Step : ', 28)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.96068543], dtype=float32))
# ('b : ', array([0.08937123], dtype=float32))
# ('hypothesis : ', array([1.0500567, 2.0107422, 2.9714274], dtype=float32))
# ('cost : ', 0.0011458196)
# ('Step : ', 29)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9616305], dtype=float32))
# ('b : ', array([0.08722281], dtype=float32))
# ('hypothesis : ', array([1.0488533, 2.0104837, 2.9721143], dtype=float32))
# ('cost : ', 0.0010913875)
# ('Step : ', 30)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.96255296], dtype=float32))
# ('b : ', array([0.08512605], dtype=float32))
# ('hypothesis : ', array([1.0476791, 2.010232 , 2.972785 ], dtype=float32))
# ('cost : ', 0.0010395477)
# ('Step : ', 31)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9634531], dtype=float32))
# ('b : ', array([0.08307964], dtype=float32))
# ('hypothesis : ', array([1.0465328, 2.009986 , 2.973439 ], dtype=float32))
# ('cost : ', 0.0009901677)
# ('Step : ', 32)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9643317], dtype=float32))
# ('b : ', array([0.08108246], dtype=float32))
# ('hypothesis : ', array([1.0454142, 2.0097458, 2.9740777], dtype=float32))
# ('cost : ', 0.00094313244)
# ('Step : ', 33)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9651891], dtype=float32))
# ('b : ', array([0.07913328], dtype=float32))
# ('hypothesis : ', array([1.0443224, 2.0095115, 2.9747007], dtype=float32))
# ('cost : ', 0.0008983319)
# ('Step : ', 34)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.96602595], dtype=float32))
# ('b : ', array([0.07723098], dtype=float32))
# ('hypothesis : ', array([1.0432569, 2.0092828, 2.975309 ], dtype=float32))
# ('cost : ', 0.0008556598)
# ('Step : ', 35)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.96684265], dtype=float32))
# ('b : ', array([0.0753744], dtype=float32))
# ('hypothesis : ', array([1.042217 , 2.0090597, 2.9759023], dtype=float32))
# ('cost : ', 0.00081501744)
# ('Step : ', 36)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.96763974], dtype=float32))
# ('b : ', array([0.07356247], dtype=float32))
# ('hypothesis : ', array([1.0412022, 2.008842 , 2.9764817], dtype=float32))
# ('cost : ', 0.0007763042)
# ('Step : ', 37)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.96841764], dtype=float32))
# ('b : ', array([0.07179408], dtype=float32))
# ('hypothesis : ', array([1.0402117, 2.0086293, 2.977047 ], dtype=float32))
# ('cost : ', 0.0007394287)
# ('Step : ', 38)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9691769], dtype=float32))
# ('b : ', array([0.07006821], dtype=float32))
# ('hypothesis : ', array([1.0392451, 2.008422 , 2.977599 ], dtype=float32))
# ('cost : ', 0.0007043059)
# ('Step : ', 39)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.96991783], dtype=float32))
# ('b : ', array([0.06838381], dtype=float32))
# ('hypothesis : ', array([1.0383017, 2.0082195, 2.9781375], dtype=float32))
# ('cost : ', 0.00067085)
# ('Step : ', 40)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.97064096], dtype=float32))
# ('b : ', array([0.0667399], dtype=float32))
# ('hypothesis : ', array([1.0373808, 2.0080218, 2.9786627], dtype=float32))
# ('cost : ', 0.0006389847)
# ('Step : ', 41)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9713468], dtype=float32))
# ('b : ', array([0.06513555], dtype=float32))
# ('hypothesis : ', array([1.0364823, 2.0078292, 2.9791758], dtype=float32))
# ('cost : ', 0.0006086346)
# ('Step : ', 42)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9720356], dtype=float32))
# ('b : ', array([0.06356972], dtype=float32))
# ('hypothesis : ', array([1.0356053, 2.0076408, 2.9796765], dtype=float32))
# ('cost : ', 0.00057972193)
# ('Step : ', 43)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9727078], dtype=float32))
# ('b : ', array([0.06204155], dtype=float32))
# ('hypothesis : ', array([1.0347494, 2.0074573, 2.980165 ], dtype=float32))
# ('cost : ', 0.00055218587)
# ('Step : ', 44)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9733639], dtype=float32))
# ('b : ', array([0.0605501], dtype=float32))
# ('hypothesis : ', array([1.033914 , 2.007278 , 2.9806418], dtype=float32))
# ('cost : ', 0.00052595476)
# ('Step : ', 45)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9740042], dtype=float32))
# ('b : ', array([0.05909452], dtype=float32))
# ('hypothesis : ', array([1.0330987, 2.007103 , 2.981107 ], dtype=float32))
# ('cost : ', 0.00050097384)
# ('Step : ', 46)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.97462916], dtype=float32))
# ('b : ', array([0.05767394], dtype=float32))
# ('hypothesis : ', array([1.0323031, 2.0069323, 2.9815614], dtype=float32))
# ('cost : ', 0.00047717578)
# ('Step : ', 47)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.97523904], dtype=float32))
# ('b : ', array([0.05628749], dtype=float32))
# ('hypothesis : ', array([1.0315266, 2.0067656, 2.9820046], dtype=float32))
# ('cost : ', 0.0004545102)
# ('Step : ', 48)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.97583425], dtype=float32))
# ('b : ', array([0.05493437], dtype=float32))
# ('hypothesis : ', array([1.0307686, 2.0066028, 2.982437 ], dtype=float32))
# ('cost : ', 0.00043292265)
# ('Step : ', 49)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9764153], dtype=float32))
# ('b : ', array([0.05361382], dtype=float32))
# ('hypothesis : ', array([1.030029 , 2.0064445, 2.9828598], dtype=float32))
# ('cost : ', 0.00041235334)
# ('Step : ', 50)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9769821], dtype=float32))
# ('b : ', array([0.05232492], dtype=float32))
# ('hypothesis : ', array([1.029307 , 2.0062892, 2.9832714], dtype=float32))
# ('cost : ', 0.00039276757)
# ('Step : ', 51)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9775355], dtype=float32))
# ('b : ', array([0.05106708], dtype=float32))
# ('hypothesis : ', array([1.0286026, 2.006138 , 2.9836736], dtype=float32))
# ('cost : ', 0.00037411237)
# ('Step : ', 52)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9780755], dtype=float32))
# ('b : ', array([0.04983947], dtype=float32))
# ('hypothesis : ', array([1.027915 , 2.0059905, 2.984066 ], dtype=float32))
# ('cost : ', 0.0003563418)
# ('Step : ', 53)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9786026], dtype=float32))
# ('b : ', array([0.04864137], dtype=float32))
# ('hypothesis : ', array([1.027244 , 2.0058465, 2.9844491], dtype=float32))
# ('cost : ', 0.00033941484)
# ('Step : ', 54)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.979117], dtype=float32))
# ('b : ', array([0.04747206], dtype=float32))
# ('hypothesis : ', array([1.026589, 2.005706, 2.984823], dtype=float32))
# ('cost : ', 0.0003232926)
# ('Step : ', 55)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.97961897], dtype=float32))
# ('b : ', array([0.04633085], dtype=float32))
# ('hypothesis : ', array([1.0259498, 2.0055687, 2.9851878], dtype=float32))
# ('cost : ', 0.00030793567)
# ('Step : ', 56)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9801089], dtype=float32))
# ('b : ', array([0.04521709], dtype=float32))
# ('hypothesis : ', array([1.025326 , 2.005435 , 2.9855437], dtype=float32))
# ('cost : ', 0.00029330995)
# ('Step : ', 57)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9805871], dtype=float32))
# ('b : ', array([0.04413011], dtype=float32))
# ('hypothesis : ', array([1.0247172, 2.0053043, 2.9858916], dtype=float32))
# ('cost : ', 0.00027937468)
# ('Step : ', 58)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.98105377], dtype=float32))
# ('b : ', array([0.04306923], dtype=float32))
# ('hypothesis : ', array([1.024123 , 2.0051768, 2.9862304], dtype=float32))
# ('cost : ', 0.0002661062)
# ('Step : ', 59)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.98150927], dtype=float32))
# ('b : ', array([0.04203389], dtype=float32))
# ('hypothesis : ', array([1.0235431, 2.0050523, 2.9865618], dtype=float32))
# ('cost : ', 0.00025346348)
# ('Step : ', 60)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.98195374], dtype=float32))
# ('b : ', array([0.04102341], dtype=float32))
# ('hypothesis : ', array([1.0229771, 2.004931 , 2.9868848], dtype=float32))
# ('cost : ', 0.0002414233)
# ('Step : ', 61)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9823875], dtype=float32))
# ('b : ', array([0.04003721], dtype=float32))
# ('hypothesis : ', array([1.0224247, 2.0048122, 2.9871995], dtype=float32))
# ('cost : ', 0.00022995881)
# ('Step : ', 62)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.982811], dtype=float32))
# ('b : ', array([0.03907478], dtype=float32))
# ('hypothesis : ', array([1.0218858, 2.0046968, 2.9875078], dtype=float32))
# ('cost : ', 0.0002190337)
# ('Step : ', 63)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9832241], dtype=float32))
# ('b : ', array([0.03813542], dtype=float32))
# ('hypothesis : ', array([1.0213596, 2.0045836, 2.9878078], dtype=float32))
# ('cost : ', 0.0002086304)
# ('Step : ', 64)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.98362744], dtype=float32))
# ('b : ', array([0.03721869], dtype=float32))
# ('hypothesis : ', array([1.0208461, 2.0044737, 2.9881012], dtype=float32))
# ('cost : ', 0.00019871845)
# ('Step : ', 65)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.98402095], dtype=float32))
# ('b : ', array([0.03632396], dtype=float32))
# ('hypothesis : ', array([1.0203449, 2.004366 , 2.9883869], dtype=float32))
# ('cost : ', 0.00018927972)
# ('Step : ', 66)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9844051], dtype=float32))
# ('b : ', array([0.03545078], dtype=float32))
# ('hypothesis : ', array([1.0198559, 2.004261 , 2.988666 ], dtype=float32))
# ('cost : ', 0.00018028985)
# ('Step : ', 67)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.98478], dtype=float32))
# ('b : ', array([0.03459859], dtype=float32))
# ('hypothesis : ', array([1.0193787, 2.0041585, 2.9889386], dtype=float32))
# ('cost : ', 0.00017172696)
# ('Step : ', 68)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9851459], dtype=float32))
# ('b : ', array([0.03376687], dtype=float32))
# ('hypothesis : ', array([1.0189128, 2.0040588, 2.9892046], dtype=float32))
# ('cost : ', 0.00016356919)
# ('Step : ', 69)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.98550296], dtype=float32))
# ('b : ', array([0.03295512], dtype=float32))
# ('hypothesis : ', array([1.0184581, 2.003961 , 2.989464 ], dtype=float32))
# ('cost : ', 0.00015579967)
# ('Step : ', 70)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.98585147], dtype=float32))
# ('b : ', array([0.0321629], dtype=float32))
# ('hypothesis : ', array([1.0180144, 2.0038657, 2.9897172], dtype=float32))
# ('cost : ', 0.00014839951)
# ('Step : ', 71)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.98619163], dtype=float32))
# ('b : ', array([0.03138975], dtype=float32))
# ('hypothesis : ', array([1.0175813, 2.003773 , 2.9899645], dtype=float32))
# ('cost : ', 0.00014135017)
# ('Step : ', 72)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.98652357], dtype=float32))
# ('b : ', array([0.03063516], dtype=float32))
# ('hypothesis : ', array([1.0171587, 2.0036824, 2.9902058], dtype=float32))
# ('cost : ', 0.0001346365)
# ('Step : ', 73)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9868475], dtype=float32))
# ('b : ', array([0.0298987], dtype=float32))
# ('hypothesis : ', array([1.0167462, 2.0035937, 2.9904413], dtype=float32))
# ('cost : ', 0.00012823894)
# ('Step : ', 74)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.98716366], dtype=float32))
# ('b : ', array([0.02917995], dtype=float32))
# ('hypothesis : ', array([1.0163436, 2.0035074, 2.9906712], dtype=float32))
# ('cost : ', 0.00012214735)
# ('Step : ', 75)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.98747224], dtype=float32))
# ('b : ', array([0.02847848], dtype=float32))
# ('hypothesis : ', array([1.0159507, 2.003423 , 2.990895 ], dtype=float32))
# ('cost : ', 0.000116347124)
# ('Step : ', 76)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9877735], dtype=float32))
# ('b : ', array([0.0277939], dtype=float32))
# ('hypothesis : ', array([1.0155674, 2.003341 , 2.9911144], dtype=float32))
# ('cost : ', 0.00011082031)
# ('Step : ', 77)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9880673], dtype=float32))
# ('b : ', array([0.02712571], dtype=float32))
# ('hypothesis : ', array([1.015193 , 2.0032604, 2.9913275], dtype=float32))
# ('cost : ', 0.00010555624)
# ('Step : ', 78)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.98835427], dtype=float32))
# ('b : ', array([0.02647365], dtype=float32))
# ('hypothesis : ', array([1.014828 , 2.0031822, 2.9915366], dtype=float32))
# ('cost : ', 0.00010054122)
# ('Step : ', 79)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9886341], dtype=float32))
# ('b : ', array([0.0258372], dtype=float32))
# ('hypothesis : ', array([1.0144713, 2.0031054, 2.9917395], dtype=float32))
# ('cost : ', 9.5765834e-05)
# ('Step : ', 80)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9889074], dtype=float32))
# ('b : ', array([0.02521612], dtype=float32))
# ('hypothesis : ', array([1.0141236, 2.003031 , 2.9919384], dtype=float32))
# ('cost : ', 9.121738e-05)
# ('Step : ', 81)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.989174], dtype=float32))
# ('b : ', array([0.02460993], dtype=float32))
# ('hypothesis : ', array([1.0137839, 2.002958 , 2.9921322], dtype=float32))
# ('cost : ', 8.688312e-05)
# ('Step : ', 82)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.98943424], dtype=float32))
# ('b : ', array([0.02401832], dtype=float32))
# ('hypothesis : ', array([1.0134525, 2.0028868, 2.992321 ], dtype=float32))
# ('cost : ', 8.2756946e-05)
# ('Step : ', 83)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9896883], dtype=float32))
# ('b : ', array([0.02344096], dtype=float32))
# ('hypothesis : ', array([1.0131292, 2.0028176, 2.9925058], dtype=float32))
# ('cost : ', 7.882635e-05)
# ('Step : ', 84)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9899362], dtype=float32))
# ('b : ', array([0.02287745], dtype=float32))
# ('hypothesis : ', array([1.0128136, 2.0027497, 2.992686 ], dtype=float32))
# ('cost : ', 7.5080796e-05)
# ('Step : ', 85)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9901781], dtype=float32))
# ('b : ', array([0.0223275], dtype=float32))
# ('hypothesis : ', array([1.0125057, 2.0026836, 2.9928617], dtype=float32))
# ('cost : ', 7.151595e-05)
# ('Step : ', 86)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9904142], dtype=float32))
# ('b : ', array([0.02179076], dtype=float32))
# ('hypothesis : ', array([1.012205 , 2.0026193, 2.9930334], dtype=float32))
# ('cost : ', 6.8118694e-05)
# ('Step : ', 87)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.99064463], dtype=float32))
# ('b : ', array([0.02126692], dtype=float32))
# ('hypothesis : ', array([1.0119115, 2.002556 , 2.9932008], dtype=float32))
# ('cost : ', 6.488236e-05)
# ('Step : ', 88)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9908696], dtype=float32))
# ('b : ', array([0.02075569], dtype=float32))
# ('hypothesis : ', array([1.0116253, 2.0024948, 2.9933646], dtype=float32))
# ('cost : ', 6.1800114e-05)
# ('Step : ', 89)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.991089], dtype=float32))
# ('b : ', array([0.02025671], dtype=float32))
# ('hypothesis : ', array([1.0113457, 2.0024347, 2.9935238], dtype=float32))
# ('cost : ', 5.886484e-05)
# ('Step : ', 90)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9913032], dtype=float32))
# ('b : ', array([0.01976976], dtype=float32))
# ('hypothesis : ', array([1.011073 , 2.002376 , 2.9936793], dtype=float32))
# ('cost : ', 5.6069457e-05)
# ('Step : ', 91)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.99151236], dtype=float32))
# ('b : ', array([0.01929454], dtype=float32))
# ('hypothesis : ', array([1.0108069, 2.0023193, 2.9938316], dtype=float32))
# ('cost : ', 5.3405845e-05)
# ('Step : ', 92)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9917163], dtype=float32))
# ('b : ', array([0.01883068], dtype=float32))
# ('hypothesis : ', array([1.010547 , 2.0022633, 2.9939797], dtype=float32))
# ('cost : ', 5.0868915e-05)
# ('Step : ', 93)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.99191546], dtype=float32))
# ('b : ', array([0.01837801], dtype=float32))
# ('hypothesis : ', array([1.0102935, 2.002209 , 2.9941244], dtype=float32))
# ('cost : ', 4.8452595e-05)
# ('Step : ', 94)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.99210984], dtype=float32))
# ('b : ', array([0.01793622], dtype=float32))
# ('hypothesis : ', array([1.010046 , 2.0021558, 2.9942658], dtype=float32))
# ('cost : ', 4.615024e-05)
# ('Step : ', 95)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9922995], dtype=float32))
# ('b : ', array([0.01750505], dtype=float32))
# ('hypothesis : ', array([1.0098045, 2.002104 , 2.9944034], dtype=float32))
# ('cost : ', 4.395911e-05)
# ('Step : ', 96)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9924846], dtype=float32))
# ('b : ', array([0.01708425], dtype=float32))
# ('hypothesis : ', array([1.0095689, 2.0020535, 2.9945383], dtype=float32))
# ('cost : ', 4.1870455e-05)
# ('Step : ', 97)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.99266523], dtype=float32))
# ('b : ', array([0.01667354], dtype=float32))
# ('hypothesis : ', array([1.0093387, 2.002004 , 2.9946692], dtype=float32))
# ('cost : ', 3.9881696e-05)
# ('Step : ', 98)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9928416], dtype=float32))
# ('b : ', array([0.01627275], dtype=float32))
# ('hypothesis : ', array([1.0091144, 2.001956 , 2.9947975], dtype=float32))
# ('cost : ', 3.7988077e-05)
# ('Step : ', 99)
# ('X : ', array([1., 2., 3.], dtype=float32))
# ('W : ', array([0.9930137], dtype=float32))
# ('b : ', array([0.01588156], dtype=float32))
# ('hypothesis : ', array([1.0088953, 2.001909 , 2.9949226], dtype=float32))
# ('cost : ', 3.6183308e-05)
#
# === Test ===
# ('X: 5, Y:', array([4.98095], dtype=float32))
# ('X: 2.5, Y:', array([2.4984157], dtype=float32))
